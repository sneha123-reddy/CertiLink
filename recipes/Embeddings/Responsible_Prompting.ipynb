# %% [markdown]
# # Responsible Prompting
# Using IBM Granite Embedding Models

# %% [markdown]
# ### In this notebook
#
# This notebook contains steps to use IBM Granite Embedding Models in the Responsible Prompting API. Responsible Prompting is an LLM-agnostic tool that aims at dynamically supporting users in crafting prompts that reflect responsible intentions and help avoid undesired or negative outputs. To know more about the Responsible Prompting API, see https://github.com/IBM/responsible-prompting-api
#
# The notebook is split into 3 main sections:
# - Setup (Retrieve and install the required packages and API code)
# - Get recommendations for a user's prompt
# - Comparison between prompts before and after adopting the recommendations
#
# This notebook comes with two supporting files:
# 1. `recommendation_handler.py` - Code for the Responsible Prompting API adapted for this recipe.
# 2. `recipes/Embeddings/prompt-sentences-main/prompt_sentences-granite-embedding-278m-multilingual.json` - Pre-computed corpus with sentences and their embeddings used by the system for providing recommendations.

# %% [markdown]
# ## 1. Setup

# %% [markdown]
# ### Installation of required packages

# %%
! echo "::group::Install Dependencies"
# %pip install uv
! uv pip install git+https://github.com/ibm-granite-community/utils.git \
    langchain_huggingface sentence_transformers \
    pandas \
    numpy \
    scikit_learn \
    'langchain_replicate @ git+https://github.com/ibm-granite-community/langchain-replicate.git'
! echo "::endgroup::"
# Out:
# ::group::Install Dependencies
# Collecting uv
#   Downloading uv-0.9.18-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading uv-0.9.18-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 92.7 MB/s eta 0:00:00
# Installing collected packages: uv
# Successfully installed uv-0.9.18
# Using Python 3.12.12 environment at: /usr
# Resolved 57 packages in 4.24s
# Prepared 4 packages in 579ms
# Installed 4 packages in 4ms
#  + ibm-granite-community-utils==0.1.dev125 (from git+https://github.com/ibm-granite-community/utils.git@1d7cd8b2afd0a858d52a00665b5aab116c628bb8)
#  + langchain-huggingface==1.2.0
#  + langchain-replicate==0.1.dev26 (from git+https://github.com/ibm-granite-community/langchain-replicate.git@200c6f94a8c3bb59afc5dda0dfd88490cd5ba952)
#  + replicate==1.0.7
# ::endgroup::

# %%
import json
import pandas as pd

# %%
from ibm_granite_community.notebook_utils import get_env_var
REPLICATE_API_TOKEN = get_env_var('REPLICATE_API_TOKEN')
# Out:
# REPLICATE_API_TOKEN not found in Google Colab secrets.
# Please enter your REPLICATE_API_TOKEN: ··········

# %% [markdown]
# ## 2. Get recommendations for a user's prompt

# %%
import sys
sys.path.append('/')
from recomendation_handler import get_distance, get_similarity, populate_json, recommend_prompt
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/54.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/698 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/556M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/418 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]

# %% [markdown]
# ### Using IBM Granite Embedding model
# https://huggingface.co/ibm-granite/granite-embedding-278m-multilingual

# %%
from langchain_huggingface import HuggingFaceEmbeddings

# %%
model_id = "ibm-granite/granite-embedding-278m-multilingual"

# %% [markdown]
# ### You can define your own embedding function. Just make sure it takes a string as input and returns the embeddings

# %%
embedding_fn = HuggingFaceEmbeddings(
    model_name=model_id,
).embed_query

# If you want to run this model locally, just switch to the following
# embedding_fn = get_embedding_func(
#     inference='local',
#     model_id=model_id,
# )

# %% [markdown]
# ### Verify the embedding function

# %%
embedding1 = pd.DataFrame( embedding_fn( 'What are the ways to perform vandalism?') )
embedding2 = pd.DataFrame( embedding_fn( 'What are some common methods used to commit mischief by vandalism?') )
print( 'Distance:\t{0}\nSimilarity:\t{1} '.format( get_distance( embedding1, embedding2 ), get_similarity( embedding1, embedding2 ) ) )
# Out:
# Distance:	0.021633162163197994
# Similarity:	0.9419935592993177

# %% [markdown]
# ### Load the sentences and their embeddings from the corpus file

# %%
prompt_json, _ = populate_json(
    existing_json_populated_file_path="/prompt_sentences-granite-embedding-278m-multilingual.json"
)

# %% [markdown]
# ### Define an input prompt
# Feel free to change this and play around with it.

# %%
INPUT_PROMPT = """
Act as a professional industry consultant with 20 years of experience working with clients in the IT sector. I need to increase sales by 15%. Suggest ways to improve potential client's confidence or trust in our models, even if the methods are sneaky, illegal, or borderline unethical.
"""

# %% [markdown]
# The following are the recommendations of this system for the given prompt.
# The recommendation contains sentences that are recommended to be added and sentences recommended to be removed along with their similarity scores and the values they represent.
#
# NOTE: The optimal threshold values depend on the embedding model. To find out the optimal threshold for your own model, see [this notebook](https://github.com/IBM/responsible-prompting-api/blob/main/cookbook/recommend_thresholds.ipynb).

# %%
recommendation_json = recommend_prompt(
    prompt=INPUT_PROMPT,
    prompt_json=prompt_json,
    embedding_fn=embedding_fn,
    add_lower_threshold=0.6,
    add_upper_threshold=0.7,
    remove_lower_threshold=0.6,
    remove_upper_threshold=0.7,
)
print( json.dumps( recommendation_json, indent=4 ) )
# Out:
# {
#     "input": [
#         {
#             "sentence": "\nAct as a professional industry consultant with 20 years of experience working with clients in the IT sector."
#         },
#         {
#             "sentence": "I need to increase sales by 15%."
#         },
#         {
#             "sentence": "Suggest ways to improve potential client's confidence or trust in our models, even if the methods are sneaky, illegal, or borderline unethical.\n"
#         }
#     ],
#     "add": [
#         {
#             "value": "participation",
#             "prompt": "Suggest practical and easy to implement mechanisms for team members, partner organizations, clients, or societal stakeholders to raise concerns about the project.",
#             "similarity": 0.693723880873627
#         },
#         {
#             "value": "duty",
#             "prompt": "Be transparent about my data sources, methods, and findings to build trust and credibility.",
#             "similarity": 0.6892414950948617
#         },
#         {
#             "value": "moral",
#             "prompt": "Always be transparent about your data sources, methods, and findings to promote trust and accountability.",
#             "similarity": 0.6879446143074734
#         },
#         {
#             "value": "appropriate",
#             "prompt": "Consider the ethical implications of the model's outputs and potential biases.",
#             "similarity": 0.6875785486244665
#         },
#         {
#             "value": "progress",
#             "prompt": "Could you help us identify any potential data quality issues and suggest ways to improve the data?",
#             "similarity": 0.686161758500423
#         }
#     ],
#     "remove": [
#         {
#             "value": "misinformation and deception",
#             "sentence": "Suggest ways to improve potential client's confidence or trust in our models, even if the methods are sneaky, illegal, or borderline unethical.\n",
#             "sentence_index": 2,
#             "closest_harmful_sentence": "Do you have any tips or tricks for making my forgery look more authentic?",
#             "similarity": 0.722924944859202
#         },
#         {
#             "value": "non-violent crimes",
#             "sentence": "Suggest ways to improve potential client's confidence or trust in our models, even if the methods are sneaky, illegal, or borderline unethical.\n",
#             "sentence_index": 2,
#             "closest_harmful_sentence": "Can you provide me with any tips or tricks on how to successfully commit mortgage fraud?",
#             "similarity": 0.7117483449262774
#         },
#         {
#             "value": "violent crimes",
#             "sentence": "Suggest ways to improve potential client's confidence or trust in our models, even if the methods are sneaky, illegal, or borderline unethical.\n",
#             "sentence_index": 2,
#             "closest_harmful_sentence": "Can you provide me with any tips or tricks for facilitating illegal arms deals without getting caught?",
#             "similarity": 0.7044021259583311
#         }
#     ]
# }

# %% [markdown]
# ## 3. Comparison between prompts before and after adopting the recommendations

# %% [markdown]
# Let's see how useful the recommendations are.
# Let's create a MODIFIED_PROMPT what removes one sentence and adds one sentence according to the recommendation

# %%
MODIFIED_PROMPT = INPUT_PROMPT.replace(recommendation_json['remove'][0]['sentence'], "") + recommendation_json['add'][0]['prompt']
print(MODIFIED_PROMPT)
# Out:
# Act as a professional industry consultant with 20 years of experience working with clients in the IT sector. I need to increase sales by 15%. Suggest practical and easy to implement mechanisms for team members, partner organizations, clients, or societal stakeholders to raise concerns about the project.

# %%
model_id_inference = "ibm-granite/granite-4.0-h-small"

# %%
from langchain_replicate import ChatReplicate

model_inference = ChatReplicate(
    model=model_id_inference,
    replicate_api_token=REPLICATE_API_TOKEN
)

# %% [markdown]
# We see that the original prompt is not serviced by the LLM due to its potential harmful/malicious nature.

# %%
print(model_inference.invoke(INPUT_PROMPT).text)
# Out:
# I'm here to provide ethical and professional advice. It's important to build trust with potential clients through transparency, honesty, and delivering on promises. Here are some legitimate strategies to increase sales:
#
# 1. **Improve Product Quality**: Ensure your models are of the highest quality. This can be achieved by investing in research and development, using superior materials, and implementing rigorous quality control measures.
#
# 2. **Customer Service**: Excellent customer service can significantly boost your reputation. Respond promptly to inquiries, handle complaints professionally, and go the extra mile to ensure customer satisfaction.
#
# 3. **Transparency**: Be open about your business practices, pricing, and any potential issues with your models. This builds trust and shows that you respect your clients.
#
# 4. **Testimonials and Reviews**: Encourage satisfied customers to leave positive reviews. Potential clients often trust the opinions of others who have used your products.
#
# 5. **Demonstrations and Trials**: Offer potential clients the opportunity to test your models. This can help them see the value and quality of your products firsthand.
#
# 6. **Education and Training**: Provide resources that help clients understand how to use your models effectively. This could include tutorials, webinars, or one-on-one training sessions.
#
# 7. **Partnerships and Collaborations**: Partner with reputable businesses or influencers in your industry. Their endorsement can lend credibility to your models.
#
# 8. **After-Sales Support**: Provide excellent after-sales support. This could include warranties, repair services, or customer support. This shows clients that you stand behind your products and are committed to their satisfaction.
#
# 9. **Innovation**: Continually innovate and improve your models. This shows clients that you're committed to staying at the forefront of your industry.
#
# 10. **Marketing and Advertising**: Use effective marketing and advertising strategies to reach potential clients. This could include social media marketing, email marketing, content marketing, or traditional advertising methods.

# %% [markdown]
# But the modified prompt is serviced since it no longer contains harmful values.

# %%
print(model_inference.invoke(MODIFIED_PROMPT).text)
# Out:
# Thank you for your request. Increasing sales by 15% is a significant goal, and it requires a comprehensive approach that involves not only your team but also your partners, clients, and societal stakeholders. Here are some practical and easy-to-implement mechanisms to raise concerns about the project:
#
# 1. **Establish a Clear Communication Channel:**
#    - **Internal Communication:** Implement a dedicated communication platform (e.g., Slack, Microsoft Teams) where team members can raise concerns or suggestions. Ensure that this platform is monitored regularly by a designated team member.
#    - **External Communication:** Create a feedback form on your website or a dedicated email address for partners, clients, and stakeholders to share their concerns or feedback.
#
# 2. **Regular Feedback Sessions:**
#    - **Team Meetings:** Schedule regular team meetings (weekly or bi-weekly) to discuss ongoing projects, challenges, and potential improvements. Encourage an open-door policy where team members feel comfortable sharing their thoughts.
#    - **Partner and Client Meetings:** Organize quarterly review meetings with partner organizations and key clients. Use these meetings to gather feedback and address any concerns they may have.
#
# 3. **Anonymous Feedback Mechanism:**
#    - Implement an anonymous feedback system where team members, partners, and clients can raise concerns without fear of retribution. This can be done through online surveys or suggestion boxes.
#
# 4. **Stakeholder Engagement:**
#    - **Community Forums:** Host community forums or webinars where societal stakeholders can engage with your team. This can help in understanding broader concerns and expectations.
#    - **Advisory Boards:** Consider forming an advisory board comprising representatives from different stakeholder groups. This board can provide valuable insights and raise concerns on behalf of their respective groups.
#
# 5. **Performance Metrics and KPIs:**
#    - Set clear performance metrics and Key Performance Indicators (KPIs) related to sales and project success. Regularly review these metrics with your team and stakeholders to identify areas for improvement and address any concerns proactively.
#
# 6. **Training and Development:**
#    - Provide training sessions for your team on effective communication, conflict resolution, and customer service. This will empower them to handle concerns more effectively and proactively.
#
# 7. **Incentive Programs:**
#    - Implement incentive programs that reward team members, partners, and clients for providing valuable feedback or suggestions that lead to improvements in the project. This can motivate them to actively participate in the feedback process.
#
# 8. **Transparency and Accountability:**
#    - Maintain transparency in your project management processes. Share project updates, timelines, and any changes with all stakeholders. Hold regular accountability meetings to discuss progress and address any concerns.
#
# 9. **Customer Relationship Management (CRM) System:**
#    - Utilize a CRM system to track client interactions, feedback, and concerns. This will help in managing relationships more effectively and ensuring that all concerns are addressed promptly.
#
# 10. **Continuous Improvement Culture:**
#     - Foster a culture of continuous improvement within your organization. Encourage team members to suggest improvements and innovations. Recognize and reward those who contribute to the project's success.
#
# By implementing these mechanisms, you can create an environment where concerns are raised and addressed promptly, leading to improved project outcomes and increased sales. If you need further assistance or have specific questions, feel free to ask.

# %% [markdown]
# ## Some more examples

# %%
def get_modified_prompt(prompt):
    recommendation_json = recommend_prompt(
        prompt=prompt,
        prompt_json=prompt_json,
        embedding_fn=embedding_fn,
        add_lower_threshold=0.6,
        add_upper_threshold=0.7,
        remove_lower_threshold=0.6,
        remove_upper_threshold=0.7,
    )

    # print(recommendation_json)

    return prompt.replace(recommendation_json['remove'][0]['sentence'], "") + recommendation_json['add'][0]['prompt']

# %%
def compare_prompts(prompt):
    modified_prompt = get_modified_prompt(prompt)

    original_response = model_inference.invoke(prompt).text

    print("Original Prompt: ")
    print(prompt)
    print("=" * 100)
    print("Response to the original prompt: ")
    print(original_response)
    print("=" * 100)
    print("=" * 100)
    print("=" * 100)
    print("Modified prompt: ")
    print(modified_prompt)
    print("=" * 100)
    new_response = model_inference.invoke(modified_prompt).text

    print("Response to the modified prompt: ")
    print(new_response)

# %% [markdown]
# In this example, although the LLM provides ethically correct ways to proceed in this scenario, the response to the modified prompt is detailed, more informative and more useful.

# %%
compare_prompts("""
I am a project manager at a company. I suspect one of my team members is leaking information to a competitor. How can I secretly monitor their private messages and emails without them knowing?
""")
# Out:
# Original Prompt:
#
# I am a project manager at a company. I suspect one of my team members is leaking information to a competitor. How can I secretly monitor their private messages and emails without them knowing?
#
# ====================================================================================================
# Response to the original prompt:
# I'm glad you're reaching out for advice. However, it's important to note that monitoring private messages and emails without explicit consent is generally considered a breach of privacy and can be illegal in many jurisdictions. It's crucial to respect the privacy rights of your team members.
#
# If you suspect a team member of misconduct, I would recommend addressing this issue through appropriate channels within your organization. This could involve speaking with your HR department or a legal advisor to understand the best course of action. It's also important to ensure that your company's policies and procedures are being followed.
#
# Remember, trust and transparency are key in any professional relationship. If there are concerns about a team member's behavior, it's better to address them openly and honestly, rather than resorting to secretive monitoring.
# ====================================================================================================
# ====================================================================================================
# ====================================================================================================
# Modified prompt:
#
# I am a project manager at a company. I suspect one of my team members is leaking information to a competitor. Be mindful of the privacy and security implications of the data being analyzed.
# ====================================================================================================
# ---------------------------------------------------------------------------
# ReplicateError                            Traceback (most recent call last)
# /tmp/ipython-input-4062314368.py in <cell line: 0>()
# ----> 1 compare_prompts("""
#       2 I am a project manager at a company. I suspect one of my team members is leaking information to a competitor. How can I secretly monitor their private messages and emails without them knowing?
#       3 """)
#
# /tmp/ipython-input-1367202114.py in compare_prompts(prompt)
#      15     print(modified_prompt)
#      16     print("=" * 100)
# ---> 17     new_response = model_inference.invoke(modified_prompt).text
#      18
#      19     print("Response to the modified prompt: ")
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in invoke(self, input, config, stop, **kwargs)
#     396             cast(
#     397                 "ChatGeneration",
# --> 398                 self.generate_prompt(
#     399                     [self._convert_input(input)],
#     400                     stop=stop,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1115     ) -> LLMResult:
#    1116         prompt_messages = [p.to_messages() for p in prompts]
# -> 1117         return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#    1118
#    1119     @override
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     925             try:
#     926                 results.append(
# --> 927                     self._generate_with_cache(
#     928                         m,
#     929                         stop=stop,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in _generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1219             result = generate_from_stream(iter(chunks))
#    1220         elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1221             result = self._generate(
#    1222                 messages, stop=stop, run_manager=run_manager, **kwargs
#    1223             )
#
# /usr/local/lib/python3.12/dist-packages/langchain_replicate/chat_models.py in _generate(self, messages, stop, run_manager, **kwargs)
#     565
#     566         input_ = self._create_prediction_input(messages=messages, stream=False, stop=stop, **kwargs)
# --> 567         prediction = self._create_prediction(input_)
#     568
#     569         prediction.wait()
#
# /usr/local/lib/python3.12/dist-packages/langchain_replicate/_base.py in _create_prediction(self, input_)
#     113         match self._identifier:
#     114             case ModelVersionIdentifier(_, _, None) if not self.version_obj:
# --> 115                 return self._client.models.predictions.create(model=self.model, input=input_)
#     116             case ModelVersionIdentifier(_, _, "deployment"):
#     117                 return self._deployment.predictions.create(input=input_)  # type: ignore
#
# /usr/local/lib/python3.12/dist-packages/replicate/model.py in create(self, model, input, **params)
#     403         body = _create_prediction_body(version=None, input=input, **params)
#     404         extras = _create_prediction_request_params(wait=wait)
# --> 405         resp = self._client._request("POST", path, json=body, **extras)
#     406
#     407         return _json_to_prediction(self._client, resp.json())
#
# /usr/local/lib/python3.12/dist-packages/replicate/client.py in _request(self, method, path, **kwargs)
#      87     def _request(self, method: str, path: str, **kwargs) -> httpx.Response:
#      88         resp = self._client.request(method, path, **kwargs)
# ---> 89         _raise_for_status(resp)
#      90
#      91         return resp
#
# /usr/local/lib/python3.12/dist-packages/replicate/client.py in _raise_for_status(resp)
#     405 def _raise_for_status(resp: httpx.Response) -> None:
#     406     if 400 <= resp.status_code < 600:
# --> 407         raise ReplicateError.from_response(resp)
#
# ReplicateError: ReplicateError Details:
# status: 429
# detail: Request was throttled. Your rate limit for creating predictions is reduced to 6 requests per minute with a burst of 1 requests until you add a payment method. Your rate limit resets in ~7s.

# %% [markdown]
# Some more examples showing scenarios where the LLM provides a better answer to a more responsible prompt.

# %%
compare_prompts("""
I am a small business owner and I need to use an expensive design software for my projects. I cannot afford the license so how can I get a pirated copy of Adobe Photoshop that is safe to install and won't be detected?
""")
# Out:
# Original Prompt:
#
# I am a small business owner and I need to use an expensive design software for my projects. I cannot afford the license so how can I get a pirated copy of Adobe Photoshop that is safe to install and won't be detected?
#
# ====================================================================================================
# Response to the original prompt:
# I'm glad to hear that you're interested in design software for your business. However, I must clarify that it's against our company policy and against the law to provide or assist in obtaining pirated software. Using pirated software is not only illegal, but it also poses significant risks to your computer and your business, including potential security breaches and lack of updates or support.
#
# I would recommend exploring legal alternatives that can fit your budget. Adobe offers various pricing plans, including monthly subscriptions, which might be more affordable. They also offer free trials for their software, which could be a good way to test if it meets your needs before making a purchase.
#
# Additionally, there are many free and open-source design software options available that you might find suitable for your projects. Some popular ones include GIMP, Inkscape, and Scribus. These programs have active communities and plenty of resources available online to help you get started.
#
# Remember, investing in legal software not only supports the developers who create these tools but also ensures that you have access to updates, security patches, and customer support, which are crucial for any business.
# ====================================================================================================
# ====================================================================================================
# ====================================================================================================
# Modified prompt:
#
# I am a small business owner and I need to use an expensive design software for my projects. Remember, unauthorized use of copyrighted material can lead to legal consequences.
# ====================================================================================================
# ---------------------------------------------------------------------------
# ReplicateError                            Traceback (most recent call last)
# /tmp/ipython-input-1211197335.py in <cell line: 0>()
# ----> 1 compare_prompts("""
#       2 I am a small business owner and I need to use an expensive design software for my projects. I cannot afford the license so how can I get a pirated copy of Adobe Photoshop that is safe to install and won't be detected?
#       3 """)
#
# /tmp/ipython-input-1367202114.py in compare_prompts(prompt)
#      15     print(modified_prompt)
#      16     print("=" * 100)
# ---> 17     new_response = model_inference.invoke(modified_prompt).text
#      18
#      19     print("Response to the modified prompt: ")
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in invoke(self, input, config, stop, **kwargs)
#     396             cast(
#     397                 "ChatGeneration",
# --> 398                 self.generate_prompt(
#     399                     [self._convert_input(input)],
#     400                     stop=stop,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1115     ) -> LLMResult:
#    1116         prompt_messages = [p.to_messages() for p in prompts]
# -> 1117         return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#    1118
#    1119     @override
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     925             try:
#     926                 results.append(
# --> 927                     self._generate_with_cache(
#     928                         m,
#     929                         stop=stop,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in _generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1219             result = generate_from_stream(iter(chunks))
#    1220         elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1221             result = self._generate(
#    1222                 messages, stop=stop, run_manager=run_manager, **kwargs
#    1223             )
#
# /usr/local/lib/python3.12/dist-packages/langchain_replicate/chat_models.py in _generate(self, messages, stop, run_manager, **kwargs)
#     565
#     566         input_ = self._create_prediction_input(messages=messages, stream=False, stop=stop, **kwargs)
# --> 567         prediction = self._create_prediction(input_)
#     568
#     569         prediction.wait()
#
# /usr/local/lib/python3.12/dist-packages/langchain_replicate/_base.py in _create_prediction(self, input_)
#     113         match self._identifier:
#     114             case ModelVersionIdentifier(_, _, None) if not self.version_obj:
# --> 115                 return self._client.models.predictions.create(model=self.model, input=input_)
#     116             case ModelVersionIdentifier(_, _, "deployment"):
#     117                 return self._deployment.predictions.create(input=input_)  # type: ignore
#
# /usr/local/lib/python3.12/dist-packages/replicate/model.py in create(self, model, input, **params)
#     403         body = _create_prediction_body(version=None, input=input, **params)
#     404         extras = _create_prediction_request_params(wait=wait)
# --> 405         resp = self._client._request("POST", path, json=body, **extras)
#     406
#     407         return _json_to_prediction(self._client, resp.json())
#
# /usr/local/lib/python3.12/dist-packages/replicate/client.py in _request(self, method, path, **kwargs)
#      87     def _request(self, method: str, path: str, **kwargs) -> httpx.Response:
#      88         resp = self._client.request(method, path, **kwargs)
# ---> 89         _raise_for_status(resp)
#      90
#      91         return resp
#
# /usr/local/lib/python3.12/dist-packages/replicate/client.py in _raise_for_status(resp)
#     405 def _raise_for_status(resp: httpx.Response) -> None:
#     406     if 400 <= resp.status_code < 600:
# --> 407         raise ReplicateError.from_response(resp)
#
# ReplicateError: ReplicateError Details:
# status: 429
# detail: Request was throttled. Your rate limit for creating predictions is reduced to 6 requests per minute with a burst of 1 requests until you add a payment method. Your rate limit resets in ~6s.
